# %%
from NYTimesAPI import *
# Out:
# query_archive_all remembered!
# query_archive_entry remembered!
# query_article_number remembered!
# field_reminder remembered!
# subfield_reminder remembered!

# %%
field_reminder()
# Out:
# [u'type_of_material',
#  u'blog',
#  u'news_desk',
#  u'lead_paragraph',
#  u'headline',
#  u'abstract',
#  u'print_page',
#  u'word_count',
#  u'_id',
#  u'snippet',
#  u'source',
#  u'slideshow_credits',
#  u'web_url',
#  u'multimedia',
#  u'subsection_name',
#  u'keywords',
#  u'byline',
#  u'document_type',
#  u'pub_date',
#  u'section_name']

# %%
subfield_remindereld_remindereld_remindernt subfield_reminder('headline')
print subfield_reminder('snippet')
# Out:
# [u'main', u'kicker', u'print_headline', u'content_kicker']
# No subfields.

# %%
run_query([['snippet',None]])
# Out:
# {'snippet': [u"An oil painting by Hans Hoffmann, a 16th- century German artist, retrieved from trash in an attic, was sold today for $610,500, Sotheby Parke Bernet, the auction house, said.   Fiona Ford of Sotheby's said that the sale to a Swiss dealer was a sur...",
#   u"Prime Minister Yitzhak Shamir said today that the newly strengthened strategic cooperation between Israel and the United States ''can go a long way'' toward restoring Lebanese independence and persuading Syria to give up hopes of dominating Lebano...",
#   None,
#   None,
#   u"IN her new book, Joan Kron has    the chutzpah to ask the question   ''What is decorating?'' and   dares to answer it as well. This is a riskier undertaking than might first be imagined, because, as Miss Kron writes, there is a widespread bias aga...",
# ...

# %%
DATESnHEADLINESnSNIPPETS=run_query_matched_idx([['snippet',None],['pub_date',None],['headline','main']])

# %%
save_obj(DATESnHEADLINESnSNIPPETS,'DATESnHEADLINESnSNIPPETS')
save_workspace()
# Out:
# Saving query_archive_all ...
